# %%
import pandas as pd
df=pd.read_csv('C:/Users/DELL/Desktop/Mukund/Simplilearn/IBM Attrition Data.csv')

# %%
df
# Out:
#       Age Attrition              Department  DistanceFromHome  Education  \
# 0      41       Yes                   Sales                 1          2
# 1      49        No  Research & Development                 8          1
# 2      37       Yes  Research & Development                 2          2
# 3      33        No  Research & Development                 3          4
# 4      27        No  Research & Development                 2          1
# ...   ...       ...                     ...               ...        ...
# 1465   36        No  Research & Development                23          2
# 1466   39        No  Research & Development                 6          1
# 1467   27        No  Research & Development                 4          3
# 1468   49        No                   Sales                 2          3
# 1469   34        No  Research & Development                 8          3
#
#      EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# ...

# %%
df.head()
# Out:
#    Age Attrition              Department  DistanceFromHome  Education  \
# 0   41       Yes                   Sales                 1          2
# 1   49        No  Research & Development                 8          1
# 2   37       Yes  Research & Development                 2          2
# 3   33        No  Research & Development                 3          4
# 4   27        No  Research & Development                 2          1
#
#   EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# 0  Life Sciences                        2                4        Single
# 1  Life Sciences                        3                2       Married
# 2          Other                        4                3        Single
# 3  Life Sciences                        4                3       Married
# 4        Medical                        1                2       Married
#
#    MonthlyIncome  NumCompaniesWorked  WorkLifeBalance  YearsAtCompany
# ...

# %%
df.loc[:,"Department"]
# Out:
# 0       41
# 1       49
# 2       37
# 3       33
# 4       27
#         ..
# 1465    36
# 1466    39
# 1467    27
# 1468    49
# 1469    34
# Name: Age, Length: 1470, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'Department', 'DistanceFromHome', 'Education',
#        'EducationField', 'EnvironmentSatisfaction', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'WorkLifeBalance', 'YearsAtCompany'],
#       dtype='object')

# %%
df["Age"].value_counts()
# Out:
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 33    58
# 38    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 25    26
# 24    26
# 49    24
# 47    24
# 55    22
# 51    19
# 53    19
# 48    19
# 54    18
# 52    18
# 22    16
# 56    14
# 23    14
# 58    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: Age, dtype: int64

# %%
df["Age"].value_counts(dropna=False)
# Out:
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 33    58
# 38    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 25    26
# 24    26
# 49    24
# 47    24
# 55    22
# 51    19
# 53    19
# 48    19
# 54    18
# 52    18
# 22    16
# 56    14
# 23    14
# 58    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: Age, dtype: int64

# %%
df.groupby("Age").count()
# Out:
#      Attrition  Department  DistanceFromHome  Education  EducationField  \
# Age
# 18           8           8                 8          8               8
# 19           9           9                 9          9               9
# 20          11          11                11         11              11
# 21          13          13                13         13              13
# 22          16          16                16         16              16
# 23          14          14                14         14              14
# 24          26          26                26         26              26
# 25          26          26                26         26              26
# 26          39          39                39         39              39
# 27          48          48                48         48              48
# 28          48          48                48         48              48
# 29          68          68                68         68              68
# ...

# %%
df["Attrition"].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
df['Age'].(ascending=True)
# Out:
# 57     4
# 60     5
# 18     8
# 19     9
# 59    10
# 20    11
# 21    13
# 58    14
# 23    14
# 56    14
# 22    16
# 52    18
# 54    18
# 48    19
# 53    19
# 51    19
# 55    22
# 47    24
# 49    24
# 25    26
# 24    26
# 50    30
# 43    32
# 46    33
# 44    33
# 26    39
# 41    40
# 45    41
# 39    42
# 42    46
# 28    48
# 27    48
# 37    50
# 40    57
# 38    58
# 33    58
# 30    60
# 32    61
# 29    68
# 31    69
# 36    69
# 34    77
# 35    78
# Name: Age, dtype: int64

# %%
df["Attrition"].count
# Out:
# <bound method Series.count of 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467     No
# 1468     No
# 1469     No
# Name: Attrition, Length: 1470, dtype: object>

# %%
df['Age'].value_counts(bins=45)
# Out:
# (34.8, 35.733]                  78
# (33.867, 34.8]                  77
# (35.733, 36.667]                69
# (30.133, 31.067]                69
# (28.267, 29.2]                  68
# (31.067, 32.0]                  61
# (29.2, 30.133]                  60
# (37.6, 38.533]                  58
# (32.933, 33.867]                58
# (39.467, 40.4]                  57
# (36.667, 37.6]                  50
# (26.4, 27.333]                  48
# (27.333, 28.267]                48
# (41.333, 42.267]                46
# (38.533, 39.467]                42
# (44.133, 45.067]                41
# (40.4, 41.333]                  40
# (25.467, 26.4]                  39
# (43.2, 44.133]                  33
# (45.067, 46.0]                  33
# (42.267, 43.2]                  32
# (49.733, 50.667]                30
# (24.533, 25.467]                26
# (23.6, 24.533]                  26
# (48.8, 49.733]                  24
# (46.933, 47.867]                24
# (54.4, 55.333]                  22
# ...

# %%
@how to find the total count of specific value

# %%
df.Attrition.value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
df["Education"].value_counts()
# Out:
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: Education, dtype: int64

# %%
#Number of DataFrame rows and columns (including NA elements).

# %%
df.shape
# Out:
# (1470, 13)

# %%
df.Age.isna
# Out:
# <bound method Series.isna of 0       41
# 1       49
# 2       37
# 3       33
# 4       27
#         ..
# 1465    36
# 1466    39
# 1467    27
# 1468    49
# 1469    34
# Name: Age, Length: 1470, dtype: int64>

# %%
df.count(axis="columns")
# Out:
# 0       13
# 1       13
# 2       13
# 3       13
# 4       13
#         ..
# 1465    13
# 1466    13
# 1467    13
# 1468    13
# 1469    13
# Length: 1470, dtype: int64

# %%
df.head(n=100)
# Out:
#     Age Attrition              Department  DistanceFromHome  Education  \
# 0    41       Yes                   Sales                 1          2
# 1    49        No  Research & Development                 8          1
# 2    37       Yes  Research & Development                 2          2
# 3    33        No  Research & Development                 3          4
# 4    27        No  Research & Development                 2          1
# ..  ...       ...                     ...               ...        ...
# 95   54        No  Research & Development                 2          4
# 96   24        No                   Sales                 3          2
# 97   28        No                   Sales                 4          3
# 98   58        No                   Sales                10          4
# 99   44        No  Research & Development                23          3
#
#       EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# ...

# %%
df.tail(n=25)
# Out:
#       Age Attrition              Department  DistanceFromHome  Education  \
# 1445   41        No  Research & Development                28          4
# 1446   34        No                   Sales                28          3
# 1447   36        No                   Sales                15          4
# 1448   41        No                   Sales                 3          3
# 1449   32        No  Research & Development                 2          3
# 1450   35        No         Human Resources                26          4
# 1451   38        No                   Sales                10          2
# 1452   50       Yes                   Sales                 1          4
# 1453   36        No                   Sales                11          4
# 1454   45        No                   Sales                20          3
# 1455   40        No  Research & Development                 2          4
# 1456   35        No  Research & Development                18          4
# ...

# %%
df.Department.value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
df.sample(n=10)
# Out:
#       Age Attrition              Department  DistanceFromHome  Education  \
# 355    26        No                   Sales                 1          3
# 864    41       Yes  Research & Development                 5          2
# 771    54        No                   Sales                 2          4
# 1231   46        No  Research & Development                13          4
# 652    37        No                   Sales                19          2
# 1151   28        No  Research & Development                27          3
# 1062   44        No  Research & Development                 2          1
# 412    46        No  Research & Development                18          3
# 1372   39        No  Research & Development                 9          2
# 617    44        No  Research & Development                 4          3
#
#      EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# 355   Life Sciences                        3                3       Married
# ...

# %%
df[['Age','Attrition']].value_counts()
# Out:
# Age  Attrition
# 34   No           68
# 35   No           68
# 36   No           63
# 38   No           56
# 40   No           52
#                   ..
# 48   Yes           2
# 45   Yes           2
# 53   Yes           2
# 51   Yes           2
# 38   Yes           2
# Length: 82, dtype: int64

# %%
df[0:2]
# Out:
#    Age Attrition              Department  DistanceFromHome  Education  \
# 0   41       Yes                   Sales                 1          2
# 1   49        No  Research & Development                 8          1
#
#   EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# 0  Life Sciences                        2                4        Single
# 1  Life Sciences                        3                2       Married
#
#    MonthlyIncome  NumCompaniesWorked  WorkLifeBalance  YearsAtCompany
# 0           5993                   8                1               6
# 1           5130                   1                3              10

# %%
df[:5]
# Out:
#    Age Attrition              Department  DistanceFromHome  Education  \
# 0   41       Yes                   Sales                 1          2
# 1   49        No  Research & Development                 8          1
# 2   37       Yes  Research & Development                 2          2
# 3   33        No  Research & Development                 3          4
# 4   27        No  Research & Development                 2          1
#
#   EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# 0  Life Sciences                        2                4        Single
# 1  Life Sciences                        3                2       Married
# 2          Other                        4                3        Single
# 3  Life Sciences                        4                3       Married
# 4        Medical                        1                2       Married
#
#    MonthlyIncome  NumCompaniesWorked  WorkLifeBalance  YearsAtCompany
# ...

# %%
df.loc[0:3]
# Out:
#    Age Attrition              Department  DistanceFromHome  Education  \
# 0   41       Yes                   Sales                 1          2
# 1   49        No  Research & Development                 8          1
# 2   37       Yes  Research & Development                 2          2
# 3   33        No  Research & Development                 3          4
#
#   EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# 0  Life Sciences                        2                4        Single
# 1  Life Sciences                        3                2       Married
# 2          Other                        4                3        Single
# 3  Life Sciences                        4                3       Married
#
#    MonthlyIncome  NumCompaniesWorked  WorkLifeBalance  YearsAtCompany
# 0           5993                   8                1               6
# 1           5130                   1                3              10
# ...

# %%
df.iloc[0:3,0:2]
# Out:
#    Age Attrition
# 0   41       Yes
# 1   49        No
# 2   37       Yes

# %%
AgeGreter45=df.loc[df['Age']>45]
AgeGreter45
# Out:
#       Age Attrition              Department  DistanceFromHome  Education  \
# 1      49        No  Research & Development                 8          1
# 6      59        No  Research & Development                 3          3
# 18     53        No                   Sales                 2          4
# 25     53        No  Research & Development                 5          3
# 29     46        No                   Sales                 2          4
# ...   ...       ...                     ...               ...        ...
# 1441   56        No  Research & Development                 1          4
# 1444   56       Yes  Research & Development                 7          2
# 1452   50       Yes                   Sales                 1          4
# 1461   50       Yes                   Sales                28          3
# 1468   49        No                   Sales                 2          3
#
#         EducationField  EnvironmentSatisfaction  JobSatisfaction  \
# ...

# %%
AgeGreter45["Age"].value_counts()
AgeGreter45.shape
# Out:
# (273, 13)

# %%
df
# Out:
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# 2     Research & Development                 2          2          Other
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EnvironmentSatisfaction  JobSatisfaction MaritalStatus  MonthlyIncome  \
# ...

# %%
df
# Out:
#       Age Attrition              Department  DistanceFromHome  Education  \
# 0      41       Yes                   Sales                 1          2
# 1      49        No  Research & Development                 8          1
# 2      37       Yes  Research & Development                 2          2
# 3      33        No  Research & Development                 3          4
# 4      27        No  Research & Development                 2          1
# ...   ...       ...                     ...               ...        ...
# 1465   36        No  Research & Development                23          2
# 1466   39        No  Research & Development                 6          1
# 1467   27        No  Research & Development                 4          3
# 1468   49        No                   Sales                 2          3
# 1469   34        No  Research & Development                 8          3
#
#      EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# ...

# %%
df.rename(columns={"Age":"age","Attrition":"Atri"})
# Out:
#       age Atri              Department  DistanceFromHome  Education  \
# 0      41  Yes                   Sales                 1          2
# 1      49   No  Research & Development                 8          1
# 2      37  Yes  Research & Development                 2          2
# 3      33   No  Research & Development                 3          4
# 4      27   No  Research & Development                 2          1
# ...   ...  ...                     ...               ...        ...
# 1465   36   No  Research & Development                23          2
# 1466   39   No  Research & Development                 6          1
# 1467   27   No  Research & Development                 4          3
# 1468   49   No                   Sales                 2          3
# 1469   34   No  Research & Development                 8          3
#
#      EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# ...

# %%
df.DistanceFromHome.min()
# Out:
# 1

# %%
df.DistanceFromHome.max()
# Out:
# 29

# %%
df.Age.mean()
# Out:
# 36.923809523809524

# %%
df.Age.median()
# Out:
# 36.0
